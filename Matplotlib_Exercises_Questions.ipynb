# %% [markdown]
# <a href="https://colab.research.google.com/github/barzansaeedpour/python-exercises/blob/main/Matplotlib_Exercises_Questions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Matplotlib Exercises

# %% [markdown]
# جاهای خالی را با کدهای خودتان پرکنید و جوابی منطق با جواب نمونه تولید کنید

# %% [markdown]
# Loading the dataset:

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

url = "https://raw.githubusercontent.com/datasciencedojo/datasets/master/titanic.csv"
df = pd.read_csv(url)

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Information about Dataset:

# %% [markdown]
# 1- **PassengerId**: A unique identifier for each passenger.
#
# 2- **Survived**: Indicates if the passenger survived (1) or not (0).
#
# 3- **Pclass**: Passenger's class (1 = 1st class, 2 = 2nd class, 3 = 3rd class).
#
# 4- **Name**: The full name of the passenger.
#
# 5- **Sex**: The gender of the passenger.
#
# 6- **Age**: The age of the passenger.
#
# 7- **SibSp**: Number of siblings/spouses aboard the Titanic.
#
# 8- **Parch**: Number of parents/children aboard the Titanic.
#
# 9- **Ticket**: The ticket number of the passenger.
#
# 10- **Fare**: The amount of money the passenger paid for the ticket.
#
# 11- **Cabin**: The cabin number where the passenger stayed. This column often has missing values.
#
# 12- **Embarked**: The port where the passenger boarded the Titanic (C = Cherbourg; Q = Queenstown; S = Southampton).

# %% [markdown]
# ### 1- Plot a bar chart of the number of passengers in each class:
#
# what this code does is create a bar chart that visualizes the number of passengers in each class on the Titanic, nicely labeled and titled for clarity.

# %%
df[.....].value_counts().sort_index().plot(kind=....., color='skyblue')
plt.title('Number of Passengers in Each Class')
plt.xlabel('Class')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
# ### 2- Create a histogram of passenger ages:
#
# This code creates a histogram that visualizes the distribution of ages among the Titanic passengers, with clearly labeled axes and a title. You get to see how many passengers fall into each age group.

# %%
df[....].plot(kind=...., bins=20, edgecolor='black')
plt.title('Distribution of Passenger Ages')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### 3- Plot a pie chart of the survival rate (survived vs not survived):
#
# What this code does is create a pie chart that visualizes the survival rate of Titanic passengers, clearly showing the proportion of those who survived and those who didn't.

# %%
survival_counts = df[......].value_counts()
survival_counts.plot(kind=....., labels=[......, 'Survived'], autopct='%1.1f%%', startangle=90, colors=['lightcoral', 'lightgreen'])
plt.title('Survival Rate')
plt.ylabel('')
plt.show()

# %% [markdown]
# ### 4- Create a scatter plot of age vs fare with different colors for survived vs not survived:
#
# This code essentially creates a scatter plot comparing the ages and fares of passengers who survived vs those who did not, with different colors representing each group.

# %%
plt.scatter(df[df[......] == 1]['Age'], df[df[......] == 1][.....], color='lightgreen', label='Survived')
plt.scatter(df[df[......] == 0]['Age'], df[df[......] == 0][.....], color='lightcoral', label='Not Survived')
plt.title('Age vs Fare')
plt.xlabel('Age')
plt.ylabel('Fare')
plt.legend()
plt.show()

# %% [markdown]
# ### 5- Plot a boxplot of passenger ages grouped by class:
#
# This code creates a boxplot visualizing the distribution of passenger ages, grouped by their class (Pclass). Each box represents the interquartile range (IQR) and shows the median age within each class, with the boxes colored sky blue for better visibility.

# %%
df.boxplot(column=....., by=....., grid=False, patch_artist=True, boxprops=dict(facecolor='skyblue'))
plt.title('Passenger Ages by Class')
plt.suptitle('')
plt.xlabel('Class')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# ### 6- Create a line plot of the average fare over different age groups:
#
# This code effectively categorizes the passengers into age groups and visualizes the average fare for each age group using a line chart.

# %%
df[.....] = pd.cut(df[.....], bins=[0, 12, 19, 59, 99], labels=['Child', 'Teen', ....., .....])
avg_fare_by_age_group = df.groupby('AgeGroup', observed=True)['Fare'].mean()
avg_fare_by_age_group.plot(kind='line', marker='o', linestyle='-')
plt.title('Average Fare by Age Group')
plt.xlabel('Age Group')
plt.ylabel('Average Fare')
plt.show()

# %% [markdown]
# ### 7- Plot a heatmap of the correlation matrix:
#
# This code effectively visualizes the correlation matrix of the numeric columns in the DataFrame as a heatmap, making it easy to see which variables are positively or negatively correlated.

# %%
numeric_df = df.select_dtypes(include=[np.number])
correlation_matrix = numeric_df.....()
sns......(......, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ### 8- Create a pairplot of the numeric columns in the dataset:
#
# This code creates a comprehensive pairplot of all numeric columns in the Titanic dataset, giving you a powerful visualization to examine pairwise relationships and distributions of the variables.

# %%
sns......(df.select_dtypes(include=[np.number]))
plt.suptitle('Pairplot of Numeric Columns', y=1.02)
plt.show()

# %% [markdown]
# ### 9- Plot the survival rate by gender using a bar chart:
#
# This code creates a bar chart that visualizes the survival rate for each gender on the Titanic, giving a clear comparison between male and female passengers.

# %%
survival_rate_by_gender = df.groupby(.....)['Survived'].mean()
survival_rate_by_gender.plot(kind=...., color=['lightcoral', 'lightgreen'])
plt.title('Survival Rate by Gender')
plt.xlabel('Gender')
plt.ylabel('Survival Rate')
plt.show()

# %% [markdown]
# ### 10- Create a stacked bar chart of the number of passengers by class and survival status:
#
# This code effectively visualizes the number of passengers in each class, separated by survival status, using a stacked bar chart. It gives a clear view of the distribution of survivors and non-survivors across different classes.

# %%
df.groupby([....., .....]).size().unstack().plot(kind=...., stacked=True, color=['lightcoral', 'lightgreen'])
plt.title('Number of Passengers by Class and Survival Status')
plt.xlabel('Class')
plt.ylabel('Number of Passengers')
plt.show()

# %% [markdown]
# ### 11- Visualize the distribution of fares among different classes with a violin plot:
#
# This code generates a violin plot that visualizes the distribution of fares paid by passengers across different classes on the Titanic. The quartile lines inside the plot give an additional sense of the data spread and central tendency within each class.

# %%
sns......(x=...., y=...., data=...., hue='Pclass', inner='quart', palette='muted', legend=False)
plt.title('Distribution of Fares among Classes')
plt.xlabel('Class')
plt.ylabel('Fare')
plt.show()

# %% [markdown]
# ### 12- Create a subplot with two charts: one for the age distribution and one for fare distribution:
#
# This code creates a figure with two side-by-side subplots: one showing the distribution of passenger ages and the other showing the distribution of passenger fares. Each histogram is clearly labeled and titled for easy interpretation.

# %%
fig, axes = plt.subplots(1, 2, figsize=(15, 5))

# Age distribution
axes[0].hist(df[.....].dropna(), bins=20, edgecolor='black')
axes[0].set_title('Distribution of Passenger Ages')
axes[0].set_xlabel(.....)
axes[0].set_ylabel('Frequency')

# Fare distribution
axes[1].hist(df[.....], bins=20, edgecolor='black')
axes[1].set_title('Distribution of Passenger Fares')
axes[1].set_xlabel(.....)
axes[1].set_ylabel('Frequency')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### 13- Create a pairplot with hue set to 'Survived' and adjust the aesthetics:
#
# This code creates a pairplot of all numeric columns in the Titanic dataset, with points colored by survival status. It's a powerful visualization tool that helps to explore pairwise relationships and distributions of numeric variables, segmented by whether passengers survived or not.

# %%
sns......(df.dropna(), hue='Survived', palette='viridis', markers=["o", "s"], diag_kind='kde')
plt.suptitle('Pairplot of Numeric Columns by Survival Status', y=1.02)
plt.show()

# %% [markdown]
# ### 14- Plot a regression line for Age vs Fare with a confidence interval:
#
# This code creates a scatter plot of age versus fare, overlaid with a linear regression line and a confidence interval. The semi-transparent points make it easier to see overlapping data points. It provides a clear visual representation of the relationship between age and fare among Titanic passengers.

# %%
sns.lmplot(x=....., y=....., data=df, aspect=1.5, scatter_kws={'alpha':0.5})
plt.title('Regression Line of Age vs Fare with Confidence Interval')
plt.xlabel(.....)
plt.ylabel(.....)
plt.show()

# %% [markdown]
# ### 15- Create a FacetGrid of survival rate by class and gender:
#
# This code creates a grid of bar plots that visualizes the average fare paid by passengers, grouped by survival status, passenger class, and gender. Each facet in the grid corresponds to a unique combination of class and gender, making it easy to compare survival rates across different segments of the passenger population

# %%
g = sns......(df, col=....., row=....., margin_titles=True)
g.map_dataframe(sns.barplot, x=....., y=....., hue='Survived', errorbar=None, palette='muted')
g.set_axis_labels('Survived', 'Fare')
g.fig.suptitle('Survival Rate by Class and Gender', y=1.03)
plt.show()

# %% [markdown]
# ### 16- Animate a time series plot of cumulative passenger fares over time:
#
# This code creates an animated plot showing the cumulative fare of passengers over time. Each frame adds the next fare to the cumulative sum, providing a dynamic visualization of the data.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from IPython.display import HTML

# Create figure
fig, ax = plt.subplots()
line, = ax.plot([], [], lw=2)

# Set axes limits
ax.set_xlim(0, len(df))
ax.set_ylim(0, df[.....].cumsum().max())

# Title and labels
ax.set_title('Cumulative Passenger Fares Over Time')
ax.set_xlabel('Passenger Index')
ax.set_ylabel('Cumulative Fare')

# Initialize function
def init():
    line.set_data([], [])
    return line,

# Animation function
def animate(i):
    x = list(range(i))
    y = df[.....].cumsum().iloc[:i]
    line.set_data(x, y)
    return line,

# # Call animation
# ani = animation.FuncAnimation(fig, animate, init_func=init, frames=len(df), interval=10, blit=True)

# # Display the animation
# HTML(ani.to_jshtml())

# %% [markdown]
# ### 17- Create a hexbin plot of Age vs Fare:
#
# This code creates a hexbin plot that visualizes the relationship between passengers' ages and fares paid, with color intensity indicating the frequency of data points within each hexagon. A fantastic way to see patterns in dense data!

# %%
plt......(df[.....], df[.....], gridsize=50, cmap='YlGnBu', mincnt=1)
cb = plt.colorbar(label='Frequency')
plt.title('Hexbin Plot of Age vs Fare')
plt.xlabel(.....)
plt.ylabel(.....)
plt.show()

# %% [markdown]
# ### 18- Plot the survival rate by age group using a violin plot:
#
# This code generates a violin plot that visualizes the survival rates of different age groups among Titanic passengers. The split violins make it easy to compare the distributions of survival status within each age group.

# %%
sns......(x=....., y=....., hue='AgeGroup', data=df, split=True, palette='muted', inner='quart', legend=True)
plt.title('Survival Rate by Age Group')
plt.xlabel(.....)
plt.ylabel(.....)
plt.show()

# %% [markdown]
# ### 19- Plot the data using a 3D scatter plot with Age, Fare, and Pclass:
#
# This code creates a 3D scatter plot that visualizes the relationship between passengers' ages, fares, and class, with the points colored based on whether the passengers survived or not. It's a powerful way to see how these three variables interact.

# %%
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(10, 7))
ax = fig.add_subplot(111, projection='3d')
sc = ax.scatter(df[.....], df[.....], df[.....], c=df['Survived'], cmap='coolwarm', edgecolor='k')
ax.set_title('3D Scatter Plot of Age, Fare, and Class')
ax.set_xlabel(.....)
ax.set_ylabel(.....)
ax.set_zlabel(.....)
legend1 = ax.legend(*sc.legend_elements(), title='Survived')
ax.add_artist(legend1)
plt.show()

# %% [markdown]
# ### 20- Create a swarm plot of the passenger's age by class and survival status:
#
# This code creates a detailed swarm plot that visualizes the distribution of passenger ages across different classes, with points colored by whether they survived. The dodge feature helps to separate points within each class, making the plot clearer.

# %%
sns......(x=....., y=....., hue=....., data=df, palette='coolwarm', dodge=True, size=3)
plt.title('Passenger Age by Class and Survival Status')
plt.xlabel(.....)
plt.ylabel(.....)
plt.legend(title='Survived')
plt.show()
